# %%
df=spark.read.parquet(
                    "abfss://staging@energystorageac.dfs.core.windows.net/datasets/parquet/device_metrics_stream.parquet",
                    header=True,
                    inferSchema=True
                  )

# %%
df.show(5)

# %%
# %sql
show catalogs;

# %%
# %sql
show external locations;

# %%
# %sql
DESCRIBE EXTERNAL LOCATION extlocenergy;

# %%
# %sql
CREATE TABLE azuredb_cen.bronze.device_metrics_stream
USING parquet
OPTIONS (
    path 'abfss://staging@energystorageac.dfs.core.windows.net/datasets/parquet/device_metrics_stream.parquet'

);

# %%
# %sql
CREATE TABLE azuredb_cen.bronze.device_metrics_stream
USING parquet
OPTIONS (
    path 'abfss://staging@energystorageac.dfs.core.windows.net/datasets/parquet/device_metrics_stream.parquet'

);

# %%
# %sql
CREATE TABLE azuredb_cen.bronze.energy_usage_stream
USING parquet
OPTIONS (
    path 'abfss://staging@energystorageac.dfs.core.windows.net/datasets/parquet/energy_usage_stream.parquet'

);

# %%
# %sql
CREATE TABLE azuredb_cen.bronze.energy_usage_stream
USING parquet
OPTIONS (
    path 'abfss://staging@energystorageac.dfs.core.windows.net/datasets/parquet/energy_usage_stream.parquet'

);

# %%
# %sql
CREATE TABLE azuredb_cen.bronze.energy_usage_stream
USING parquet
OPTIONS (
    path 'abfss://staging@energystorageac.dfs.core.windows.net/datasets/parquet/energy_usage_stream.parquet'

);

# %%
# %sql
CREATE TABLE azuredb_cen.bronze.energy_usage_stream
USING parquet
OPTIONS (
    path 'abfss://staging@energystorageac.dfs.core.windows.net/datasets/parquet/energy_usage_stream.parquet'

);

# %%
# %sql
CREATE TABLE azuredb_cen.bronze.grid_load_stream
USING parquet
OPTIONS (
    path 'abfss://staging@energystorageac.dfs.core.windows.net/datasets/parquet/grid_load_stream.parquet'

);

# %%
# %sql
CREATE TABLE azuredb_cen.bronze.tariff_metrics_stream_v2
USING parquet
OPTIONS (
    path 'abfss://staging@energystorageac.dfs.core.windows.net/datasets/parquet/tariff_metrics_stream_v2.parquet'

);

# %%
# %sql
CREATE TABLE azuredb_cen.bronze.weather_source_v2
USING parquet
OPTIONS (
    path 'abfss://staging@energystorageac.dfs.core.windows.net/datasets/parquet/weather_source_v2.parquet'

);
